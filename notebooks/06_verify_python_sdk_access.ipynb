# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

# Connect using your az login credentials
credential = DefaultAzureCredential()
ml_client = MLClient(
    credential=credential,
    subscription_id="c0f8052d-a51b-4204-988c-ed16de59510d",
    resource_group_name="rg-greekdam-dev-westeu",
    workspace_name="mlw-greekdam-dev-westeu",
)

# Verify by listing existing compute (should be empty for now)
computes = list(ml_client.compute.list())
print(f"Compute targets: {len(computes)}")

# List datastores
datastores = list(ml_client.datastores.list())
print(f"Datastores: {[ds.name for ds in datastores]}")
# Out:
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Compute targets: 0
# Datastores: ['raw_data', 'curated_data', 'processed_data', 'workspaceartifactstore', 'workspacefilestore', 'workspaceworkingdirectory', 'workspaceblobstore']
